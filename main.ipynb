# %% [markdown]
# data(pair nodes) -> encoder -> alpha_ij_hat -> predict -> x_{t+1}_hat
#                              (+node features)             (+x_{t+1})
#                                                           (+ _lambda * CELoss(alpha_ij_hat, alpha_ij))

# %%
import main

# %%
main.main()
# Out:
#                0            1         2
# 0      castellon    castellon   82370.0
# 1        granada         jaen     171.0
# 2        granada      granada  130649.0
# 3    ciudad_real  ciudad_real   65593.0
# 4         burgos       burgos   32439.0
# ..           ...          ...       ...
# 125       lleida    tarragona      13.0
# 126       girona       lleida      11.0
# 127    barcelona    castellon      47.0
# 128       cuenca     valencia      20.0
# 129     albacete  ciudad_real      37.0
#
# [130 rows x 3 columns]
# --------------------
